# %%
from activities.enviroment import Env
from activities.base import BaseActivity

# %%
e = Env()

# %%
# Activity list
def a1(a):
    return a + 1

def a2(a):
    print(a * 2)

def a3(a):
    print("process finished")

ba1 = BaseActivity(env=e,id="add_one",function=a1,output_name="a")
ba2 = BaseActivity(env=e,id="multiply_two",function=a2,parent=ba1,output_name="a")
ba3 = BaseActivity(env=e,id="print",function=a3,parent=ba1,output_name="a")

e.show()
# Out:
# 12000

# %%
import polars as pl


from ..activities.base import BaseActivity
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 4
#       1 import polars as pl
# ----> 4 from ..activities.base import BaseActivity
#
# ImportError: attempted relative import with no known parent package
